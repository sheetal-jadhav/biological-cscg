# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# parameters
dt = 1.0    # ms
T = 1000    # total simulation time (ms)
K = 5       # neurons in WTA
R_max = 100 # Hz total rate in WTA

rng = np.random.default_rng(0)

# %%
w = np.zeros((K,K),dtype=float)
bias = np.zeros(K,dtype=float)

ext_input = np.zeros((T,K))
